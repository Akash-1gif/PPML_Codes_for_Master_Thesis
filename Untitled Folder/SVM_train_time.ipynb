# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### CKKS (With rescaling, training time graphs):

# %%
low_attr_varying_instance_training_time=[45,81,126]
mid_attr_varying_instance_training_time=[56,106,160]
high_attr_varying_instance_training_time=[54,99,156]

low_inst_varying_attr_training_time=[45,56,54]
mid_inst_varying_attr_training_time=[81,106,99]
high_inst_varying_attr_training_time=[126,160,156]

# %%
x_values=[360,680,1080]
plt.xticks(x_values)

plt.plot(x_values,low_attr_varying_instance_training_time, marker='o', label='low attr')
plt.plot(x_values,mid_attr_varying_instance_training_time, marker='o', label='mid attr')
plt.plot(x_values,high_attr_varying_instance_training_time, marker='o', label='high attr')
# Add labels and title
plt.xlabel('Increase in number of instances')
plt.ylabel('training time')
plt.title('Line Graph of training time wrt increase in number of instances')
plt.legend()
plt.show()

# %%
x_values=[8,15,22]
plt.xticks(x_values)

plt.plot(x_values,low_inst_varying_attr_training_time, marker='o', label='low inst')
plt.plot(x_values,mid_inst_varying_attr_training_time, marker='o', label='mid inst')
plt.plot(x_values,high_inst_varying_attr_training_time, marker='o', label='high inst')
# Add labels and title
plt.xlabel('Increase in number of attributes')
plt.ylabel('training time')
plt.title('Line Graph of training time wrt increase in number of attributes')
plt.legend()
plt.show()

# %% [markdown]
# ### Paillier:

# %%
low_attr_varying_instance_training_time=[3022,5425,8440]
mid_attr_varying_instance_training_time=[5288,9616,14098]
high_attr_varying_instance_training_time=[7012,12097,20187]

low_inst_varying_attr_training_time=[3022,5288,7012]
mid_inst_varying_attr_training_time=[5425,9616,12097]
high_inst_varying_attr_training_time=[8440,14098,20187]

# %%
x_values=[360,680,1080]
plt.xticks(x_values)

plt.plot(x_values,low_attr_varying_instance_training_time, marker='o', label='low attr')
plt.plot(x_values,mid_attr_varying_instance_training_time, marker='o', label='mid attr')
plt.plot(x_values,high_attr_varying_instance_training_time, marker='o', label='high attr')
# Add labels and title
plt.xlabel('Increase in number of instances')
plt.ylabel('training time')
plt.title('Line Graph of training time wrt increase in number of instances')
plt.legend()
plt.show()

# %%
x_values=[8,15,22]
plt.xticks(x_values)

plt.plot(x_values,low_inst_varying_attr_training_time, marker='o', label='low inst')
plt.plot(x_values,mid_inst_varying_attr_training_time, marker='o', label='mid inst')
plt.plot(x_values,high_inst_varying_attr_training_time, marker='o', label='high inst')
# Add labels and title
plt.xlabel('Increase in number of attributes')
plt.ylabel('training time')
plt.title('Line Graph of training time wrt increase in number of attributes')
plt.legend()
plt.show()
