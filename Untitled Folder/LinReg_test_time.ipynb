# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### CKKS (With rescaling, training time graphs):

# %%
low_attr_varying_instance_testing_time=[1.27,2.39,4.73]
mid_attr_varying_instance_testing_time=[1.25,2.54,4.93]
high_attr_varying_instance_testing_time=[2.18,3.08,6.75]

low_inst_varying_attr_testing_time=[1.27,1.25,2.18]
mid_inst_varying_attr_testing_time=[2.39,2.54,3.08]
high_inst_varying_attr_testing_time=[4.73,4.93,4.90]

# %%
x_values=[90,170,270]
plt.xticks(x_values)

plt.plot(x_values,low_attr_varying_instance_testing_time, marker='o', label='low attr')
plt.plot(x_values,mid_attr_varying_instance_testing_time, marker='o', label='mid attr')
plt.plot(x_values,high_attr_varying_instance_testing_time, marker='o', label='high attr')
# Add labels and title
plt.xlabel('Increase in number of instances')
plt.ylabel('testing time')
plt.title('Line Graph of testing time wrt increase in number of instances')
plt.legend()
plt.show()

# %%
x_values=[5,14,21]
plt.xticks(x_values)

plt.plot(x_values,low_inst_varying_attr_testing_time, marker='o', label='low inst')
plt.plot(x_values,mid_inst_varying_attr_testing_time, marker='o', label='mid inst')
plt.plot(x_values,high_inst_varying_attr_testing_time, marker='o', label='high inst')
# Add labels and title
plt.xlabel('Increase in number of attributes')
plt.ylabel('testing time')
plt.title('Line Graph of testing time wrt increase in number of attributes')
plt.legend()
plt.show()

# %% [markdown]
# ### Paillier:

# %%
low_attr_varying_instance_testing_time=[5.33,11.06,16.48]
mid_attr_varying_instance_testing_time=[13.037,23.57,42.85]
high_attr_varying_instance_testing_time=[25.44,42.57,74.53]

low_inst_varying_attr_testing_time=[5.33,13.037,25.44]
mid_inst_varying_attr_testing_time=[11.06,23.57,42.57]
high_inst_varying_attr_testing_time=[16.48,42.85,74.53]

# %%
X_values=[90,170,270]
plt.xticks(x_values)

plt.plot(x_values,low_attr_varying_instance_testing_time, marker='o', label='low attr')
plt.plot(x_values,mid_attr_varying_instance_testing_time, marker='o', label='mid attr')
plt.plot(x_values,high_attr_varying_instance_testing_time, marker='o', label='high attr')
# Add labels and title
plt.xlabel('Increase in number of instances')
plt.ylabel('testing time')
plt.title('Line Graph of testing time wrt increase in number of instances')
plt.legend()
plt.show()

# %%
x_values=[5,14,21]
plt.xticks(x_values)

plt.plot(x_values,low_inst_varying_attr_testing_time, marker='o', label='low inst')
plt.plot(x_values,mid_inst_varying_attr_testing_time, marker='o', label='mid inst')
plt.plot(x_values,high_inst_varying_attr_testing_time, marker='o', label='high inst')
# Add labels and title
plt.xlabel('Increase in number of attributes')
plt.ylabel('testing time')
plt.title('Line Graph of testing time wrt increase in number of attributes')
plt.legend()
plt.show()
