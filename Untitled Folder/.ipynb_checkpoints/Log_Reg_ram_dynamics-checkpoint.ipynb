# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### CKKS (With rescaling, training time graphs):

# %%
low_attr_varying_inst_ram=[5.16,8.63,11.73]
mid_attr_varying_inst_ram=[4.33,7.83,11.92]
high_attr_varying_inst_ram=[4.32,7.70,11.11]

low_inst_varying_attr_ram=[5.16,4.33,4.32]
mid_inst_varying_attr_ram=[8.63,7.83,7.7]
high_inst_varying_attr_ram=[11.73,11.92,11.11]

# %%
x_values=[360,680,1080]
plt.xticks(x_values)

plt.plot(x_values,low_attr_varying_inst_ram, marker='o', label='low attr')
plt.plot(x_values,mid_attr_varying_inst_ram, marker='o', label='mid attr')
plt.plot(x_values,high_attr_varying_inst_ram, marker='o', label='high attr')
# Add labels and title
plt.xlabel('Increase in number of instances')
plt.ylabel('training time')
plt.title('Line Graph of ram% utilization wrt increase in number of instances')
plt.legend()
plt.show()

# %%
x_values=[8,15,22]
plt.xticks(x_values)

plt.plot(x_values,low_inst_varying_attr_ram, marker='o', label='low inst')
plt.plot(x_values,mid_inst_varying_attr_ram, marker='o', label='mid inst')
plt.plot(x_values,high_inst_varying_attr_ram, marker='o', label='high inst')
# Add labels and title
plt.xlabel('Increase in number of attributes')
plt.ylabel('training time')
plt.title('Line Graph of ram% utilization wrt increase in number of attributes')
plt.legend()
plt.show()

# %% [markdown]
# ### CKKS (Without rescaling, training time graphs):

# %%
low_attr_varying_inst_ram=[10.73,13.79,21.45]
mid_attr_varying_inst_ram=[9.47,14.07,21.74]
high_attr_varying_inst_ram=[9.47,13.79,19.19]

low_inst_varying_attr_ram=[10.73,9.47,9.47]
mid_inst_varying_attr_ram=[13.79,14.07,13.79]
high_inst_varying_attr_ram=[21.45,21.74,19.19]

# %%
x_values=[360,680,1080]
plt.xticks(x_values)

plt.plot(x_values,low_attr_varying_inst_ram, marker='o', label='low attr')
plt.plot(x_values,mid_attr_varying_inst_ram, marker='o', label='mid attr')
plt.plot(x_values,high_attr_varying_inst_ram, marker='o', label='high attr')
# Add labels and title
plt.xlabel('Increase in number of instances')
plt.ylabel('training time')
plt.title('Line Graph of ram% utilization wrt increase in number of instances')
plt.legend()
plt.show()

# %%
x_values=[8,15,22]
plt.xticks(x_values)

plt.plot(x_values,low_inst_varying_attr_ram, marker='o', label='low inst')
plt.plot(x_values,mid_inst_varying_attr_ram, marker='o', label='mid inst')
plt.plot(x_values,high_inst_varying_attr_ram, marker='o', label='high inst')
# Add labels and title
plt.xlabel('Increase in number of attributes')
plt.ylabel('training time')
plt.title('Line Graph of ram% utilization wrt increase in number of attributes')
plt.legend()
plt.show()

# %% [markdown]
# ### Paillier:

# %%
low_attr_varying_inst_ram=[1.61,1.63,1.67]
mid_attr_varying_inst_ram=[1.63,1.68,1.76]
high_attr_varying_inst_ram=[1.67,1.75,1.85]

low_inst_varying_attr_ram=[1.61,1.63,1.67]
mid_inst_varying_attr_ram=[1.63,1.68,1.75]
high_inst_varying_attr_ram=[1.67,1.76,1.85]

# %%
x_values=[360,680,1080]
plt.xticks(x_values)

plt.plot(x_values,low_attr_varying_inst_ram, marker='o', label='low attr')
plt.plot(x_values,mid_attr_varying_inst_ram, marker='o', label='mid attr')
plt.plot(x_values,high_attr_varying_inst_ram, marker='o', label='high attr')
# Add labels and title
plt.xlabel('Increase in number of instances')
plt.ylabel('training time')
plt.title('Line Graph of ram% utilization wrt increase in number of instances')
plt.legend()
plt.show()

# %%
x_values=[8,15,22]
plt.xticks(x_values)

plt.plot(x_values,low_inst_varying_attr_ram, marker='o', label='low inst')
plt.plot(x_values,mid_inst_varying_attr_ram, marker='o', label='mid inst')
plt.plot(x_values,high_inst_varying_attr_ram, marker='o', label='high inst')
# Add labels and title
plt.xlabel('Increase in number of attributes')
plt.ylabel('training time')
plt.title('Line Graph of ram% utilization wrt increase in number of attributes')
plt.legend()
plt.show()
