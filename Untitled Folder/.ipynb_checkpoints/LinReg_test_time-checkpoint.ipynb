# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### CKKS (With rescaling, training time graphs):

# %%
low_attr_varying_instance_testing_time=[1.32,4.87,6.72]
mid_attr_varying_instance_testing_time=[2.43,5.66,7.16]
high_attr_varying_instance_testing_time=[2.41,4.47,7.36]

low_inst_varying_attr_testing_time=[1.32,2.43,2.41]
mid_inst_varying_attr_testing_time=[4.87,5.66,4.47]
high_inst_varying_attr_testing_time=[6.72,7.16,7.36]

# %%
x_values=[8,15,22]
plt.xticks(x_values)

plt.plot(x_values,low_attr_varying_instance_testing_time, marker='o', label='low attr')
plt.plot(x_values,mid_attr_varying_instance_testing_time, marker='o', label='mid attr')
plt.plot(x_values,high_attr_varying_instance_testing_time, marker='o', label='high attr')
# Add labels and title
plt.xlabel('Increase in number of attributes')
plt.ylabel('training time')
plt.title('Line Graph of testing time wrt increase in number of instances')
plt.legend()
plt.show()

# %%
x_values=[90,170,270]
plt.xticks(x_values)

plt.plot(x_values,low_inst_varying_attr_testing_time, marker='o', label='low inst')
plt.plot(x_values,mid_inst_varying_attr_testing_time, marker='o', label='mid inst')
plt.plot(x_values,high_inst_varying_attr_testing_time, marker='o', label='high inst')
# Add labels and title
plt.xlabel('Increase in number of instances')
plt.ylabel('training time')
plt.title('Line Graph of testing time wrt increase in number of attributes')
plt.legend()
plt.show()

# %% [markdown]
# ### Paillier:

# %%
low_attr_varying_instance_testing_time=[118,219,359]
mid_attr_varying_instance_testing_time=[205,387,616]
high_attr_varying_instance_testing_time=[291,566,883]

low_inst_varying_attr_testing_time=[118,205,291]
mid_inst_varying_attr_testing_time=[219,387,616]
high_inst_varying_attr_testing_time=[359,616,883]

# %%
X_values=[8,15,22]
plt.xticks(x_values)

plt.plot(x_values,low_attr_varying_instance_testing_time, marker='o', label='low attr')
plt.plot(x_values,mid_attr_varying_instance_testing_time, marker='o', label='mid attr')
plt.plot(x_values,high_attr_varying_instance_testing_time, marker='o', label='high attr')
# Add labels and title
plt.xlabel('Increase in number of attributes')
plt.ylabel('training time')
plt.title('Line Graph of testing time wrt increase in number of instances')
plt.legend()
plt.show()

# %%
x_values=[90,170,270]
plt.xticks(x_values)

plt.plot(x_values,low_inst_varying_attr_testing_time, marker='o', label='low inst')
plt.plot(x_values,mid_inst_varying_attr_testing_time, marker='o', label='mid inst')
plt.plot(x_values,high_inst_varying_attr_testing_time, marker='o', label='high inst')
# Add labels and title
plt.xlabel('Increase in number of instances')
plt.ylabel('training time')
plt.title('Line Graph of testing time wrt increase in number of attributes')
plt.legend()
plt.show()
