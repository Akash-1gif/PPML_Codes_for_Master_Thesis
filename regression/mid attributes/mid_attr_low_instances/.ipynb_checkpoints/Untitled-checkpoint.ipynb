# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X_train=pd.read_csv('X_train1.csv')
X_test=pd.read_csv('X_test1.csv')
y_train=pd.read_csv('y_train1.csv')
y_test=pd.read_csv('y_test1.csv')

# %%
X_train.head()
# Out:
#    Country  Year  Status  Adult Mortality  infant deaths  Alcohol  \
# 0       66  2000       0            218.0              0     7.13
# 1       63  2000       1            292.0              9     6.00
# 2       93  2006       1            299.0             11     0.64
# 3       70  2001       0             21.0              0    10.20
# 4        0  2005       1            291.0             85     0.02
#
#    percentage expenditure          GDP  Population (in 100K)  \
# 0              291.017076  3352.731296                  2.37
# 1              112.541157  1229.958000                148.84
# 2              126.614214   854.346921                  6.47
# 3               42.872087   353.147337                  3.48
# 4                1.388648    25.294130                  2.58
#
#    Income composition of resources  Schooling  under-five deaths
# 0                            0.716       13.7                   0
# 1                            0.676       12.1                  10
# 2                            0.454        8.2                  14
# 3                            0.757       14.7                   0
# 4                            0.396        7.9                 118

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
y_test=y_test.to_numpy()

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 15.941730074749175

# %%
model.coef_
# Out:
# array([[ 1.69184990e-03,  7.53362676e-02, -6.51465071e-01,
#         -2.70613303e-02,  1.49134668e+00,  2.07068440e-02,
#          1.77244931e-03, -2.01582524e-04,  1.84991030e-03,
#          8.28084172e+00,  4.00038772e-01, -1.14920962e+00]])

# %%
model.intercept_
# Out:
# array([-86.4695215])

# %%
import joblib
joblib.dump((model.coef_,model.coef_,y_pred),'variables_sklearn.pkl')
# Out:
# ['variables_sklearn.pkl']
