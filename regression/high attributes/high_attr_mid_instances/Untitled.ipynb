# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X_train=pd.read_csv('X_train2.csv')
X_test=pd.read_csv('X_test2.csv')
y_train=pd.read_csv('y_train2.csv')
y_test=pd.read_csv('y_test2.csv')

# %%
X_train.head()
# Out:
#    Country  Year  Status  Adult Mortality  infant deaths  Alcohol  \
# 0       20  2008       1             35.0             23     4.33
# 1        8  2006       1            154.0              6     0.85
# 2        7  2003       0             88.0              0    12.20
# 3      126  2006       1            117.0              1     6.58
# 4        6  2002       0             73.0              1     9.84
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 0               15.994152         92.0       173   15.2  ...   89.0
# 1              105.633726         52.0       222   45.3  ...    8.0
# 2              504.430874         83.0        90   51.7  ...   84.0
# 3             1712.225506         95.0         0   58.9  ...   95.0
# 4               46.387182         95.0        32   59.6  ...   92.0
#
#    Total expenditure  Diphtheria    HIV/AIDS          GDP  \
# 0               7.86         92.0        2.9   196.247263
# 1               6.17         78.0        0.1  2473.857760
# 2               1.48         84.0        0.1  3212.935500
# 3              11.17         95.0        0.1  5877.876780
# 4               8.39         92.0        0.1   281.817630
#
#    Population (in 100K)   thinness  1-19 years   thinness 5-9 years  \
# 0                 82.12                    7.9                  7.9
# 1                  8.48                    2.9                  2.9
# 2                 81.21                    1.7                  1.9
# 3                  3.33                    1.6                  1.6
# 4                  1.97                    0.7                  0.7
#
#    Income composition of resources  Schooling
# 0                            0.319        7.9
# 1                            0.682       10.7
# 2                            0.837       14.7
# 3                            0.756       15.2
# 4                            0.902       20.1
#
# [5 rows x 21 columns]

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
y_test=y_test.to_numpy()

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 10.549915956551716

# %%
model.coef_
# Out:
# array([[ 6.39827503e-04, -2.63609981e-02, -1.40886701e+00,
#         -1.42763452e-02,  2.96143328e-01, -5.45694557e-02,
#         -9.60488528e-05,  2.34035036e-03, -3.85461456e-05,
#          2.95884479e-02, -2.69042903e-01, -1.55808558e-02,
#          1.60926563e-01,  4.53740353e-03, -3.96039449e-01,
#          8.15447343e-05,  2.37861650e-03, -3.44042507e-01,
#          2.74210418e-01,  9.47269939e+00,  5.28342142e-01]])

# %%
model.intercept_
# Out:
# array([113.7163447])

# %%
import joblib
joblib.dump((model.coef_,model.coef_,y_pred),'variables_sklearn.pkl')
# Out:
# ['variables_sklearn.pkl']
