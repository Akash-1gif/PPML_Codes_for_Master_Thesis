# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df.dropna(inplace=True)

# %%
upper_threshold = df['Population'].quantile(0.90)
lower_threshold = df['Population'].quantile(0.10)

# Filter the DataFrame to remove the top 5% and bottom 5% rows based on the Population column
df_filtered = df[(df['Population'] <= upper_threshold) & (df['Population'] >= lower_threshold)]

# Display the filtered DataFrame
df_filtered.shape
# Out:
# (1319, 22)

# %%
df_filtered['Population'].max()
# Out:
# 29759989.0

# %%
df_filtered['Population'].min()
# Out:
# 25885.0

# %%
df_filtered['Population'].median()
# Out:
# 1419631.0

# %%
df_filtered['Population'].mean()
# Out:
# 4314016.684601971

# %%
df_filtered['Population']=df_filtered['Population']/100000
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_24544\969936016.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Population']=df_filtered['Population']/100000

# %%
df_filtered['Population'].max()
# Out:
# 297.59989

# %%
df_filtered['Population'].min()
# Out:
# 0.25885

# %%
df_filtered.rename(columns={'Population': 'Population (in 100K)'}, inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_24544\2902226852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.rename(columns={'Population': 'Population (in 100K)'}, inplace=True)

# %%
df_filtered
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 1     Afghanistan  2014  Developing              59.9            271.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# 5     Afghanistan  2010  Developing              58.8            279.0
# 6     Afghanistan  2009  Developing              58.6            281.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 1                64     0.01               73.523582         62.0       492
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# 5                74     0.01               79.679367         66.0      1989
# 6                77     0.01               56.762217         63.0      2861
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# 5     ...   66.0               9.20         66.0        0.1  553.328940
# 6     ...   63.0               9.42         63.0        0.1  445.893298
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population (in 100K)   thinness  1-19 years   thinness 5-9 years  \
# 1                  3.27582                   17.5                 17.5
# 3                 36.96958                   17.9                 18.0
# 4                 29.78599                   18.2                 18.2
# 5                 28.83167                   18.4                 18.4
# 6                  2.84331                   18.6                 18.7
# ...                    ...                    ...                  ...
# 2933             127.77511                    9.4                  9.4
# 2934             126.33897                    9.8                  9.9
# 2935               1.25525                    1.2                  1.3
# 2936             123.66165                    1.6                  1.7
# 2937             122.22251                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 1                               0.476       10.0
# 3                               0.463        9.8
# 4                               0.454        9.5
# 5                               0.448        9.2
# 6                               0.434        8.9
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [1319 rows x 22 columns]

# %%
df_filtered['Population (in 100K)'] = df_filtered['Population (in 100K)'].round(2)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_24544\1150859451.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Population (in 100K)'] = df_filtered['Population (in 100K)'].round(2)

# %%
df_filtered.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 1  Afghanistan  2014  Developing              59.9            271.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
# 6  Afghanistan  2009  Developing              58.6            281.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 1             64     0.01               73.523582         62.0       492  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
# 5             74     0.01               79.679367         66.0      1989  ...
# 6             77     0.01               56.762217         63.0      2861  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 1   58.0               8.18         62.0        0.1  612.696514
# 3   67.0               8.52         67.0        0.1  669.959000
# 4   68.0               7.87         68.0        0.1   63.537231
# 5   66.0               9.20         66.0        0.1  553.328940
# 6   63.0               9.42         63.0        0.1  445.893298
#
#    Population (in 100K)   thinness  1-19 years   thinness 5-9 years  \
# 1                  3.28                   17.5                 17.5
# 3                 36.97                   17.9                 18.0
# 4                 29.79                   18.2                 18.2
# 5                 28.83                   18.4                 18.4
# 6                  2.84                   18.6                 18.7
#
#    Income composition of resources  Schooling
# 1                            0.476       10.0
# 3                            0.463        9.8
# 4                            0.454        9.5
# 5                            0.448        9.2
# 6                            0.434        8.9
#
# [5 rows x 22 columns]

# %%
df=df_filtered

# %%
df.shape
# Out:
# (1319, 22)

# %%
v=df['Country'].value_counts()

# %%
print(v)
# Out:
# Country
# Zimbabwe             15
# Belize               15
# Fiji                 15
# Honduras             15
# Jordan               15
#                      ..
# Ethiopia              2
# Haiti                 2
# Georgia               2
# Equatorial Guinea     1
# India                 1
# Name: count, Length: 131, dtype: int64

# %%
for i in v:
    print(i)
# Out:
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 6
# 6
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 4
# 4
# 4
# 3
# 2
# 2
# 2
# 1
# 1

# %%
# Get the value counts of the Country column
country_counts = df['Country'].value_counts()

# Print each country and its count
for country, count in country_counts.items():
    print(f'{country}: {count}')
# Out:
# Zimbabwe: 15
# Belize: 15
# Fiji: 15
# Honduras: 15
# Jordan: 15
# Lebanon: 15
# Bulgaria: 15
# Lithuania: 15
# Botswana: 15
# Costa Rica: 15
# Mongolia: 15
# Malaysia: 15
# Austria: 15
# Papua New Guinea: 15
# Belarus: 15
# Solomon Islands: 15
# Mozambique: 14
# Kazakhstan: 14
# Ecuador: 14
# El Salvador: 14
# Uruguay: 14
# Tunisia: 14
# Latvia: 14
# Albania: 14
# Romania: 14
# Panama: 14
# Luxembourg: 14
# Nicaragua: 14
# Dominican Republic: 14
# Afghanistan: 14
# Belgium: 14
# Armenia: 14
# Uzbekistan: 13
# Mauritius: 13
# Guyana: 13
# Madagascar: 13
# Swaziland: 13
# Malawi: 13
# Rwanda: 13
# Ghana: 13
# Portugal: 12
# Azerbaijan: 12
# Mexico: 12
# Nepal: 12
# Greece: 12
# Bhutan: 12
# Jamaica: 12
# Paraguay: 12
# Peru: 12
# Tajikistan: 12
# Ukraine: 12
# Cyprus: 12
# Mali: 11
# Burundi: 11
# Comoros: 11
# Australia: 11
# Malta: 11
# Serbia: 11
# Trinidad and Tobago: 11
# Turkmenistan: 11
# Cabo Verde: 11
# Benin: 11
# China: 11
# Eritrea: 10
# Mauritania: 10
# Zambia: 10
# Lesotho: 10
# Seychelles: 10
# Bosnia and Herzegovina: 10
# Guatemala: 10
# Senegal: 10
# Samoa: 10
# Poland: 10
# Germany: 9
# Gabon: 9
# France: 9
# Cameroon: 9
# Russian Federation: 9
# Estonia: 9
# Chile: 9
# Turkey: 9
# Vanuatu: 9
# Bangladesh: 9
# Philippines: 9
# Indonesia: 9
# Burkina Faso: 9
# Kenya: 9
# Cambodia: 8
# Thailand: 8
# Uganda: 8
# Brazil: 8
# Angola: 8
# Sierra Leone: 8
# Suriname: 8
# Syrian Arab Republic: 8
# Morocco: 8
# Guinea: 8
# Italy: 8
# Iraq: 7
# Liberia: 7
# Argentina: 7
# Spain: 7
# Togo: 7
# Canada: 7
# Sao Tome and Principe: 7
# Djibouti: 7
# Croatia: 7
# Montenegro: 7
# Pakistan: 7
# Nigeria: 7
# Chad: 7
# Central African Republic: 6
# Guinea-Bissau: 6
# Niger: 6
# Israel: 5
# Timor-Leste: 5
# Myanmar: 5
# South Africa: 5
# Namibia: 5
# Ireland: 5
# Colombia: 5
# Kiribati: 5
# Sweden: 4
# Algeria: 4
# Netherlands: 4
# Tonga: 3
# Ethiopia: 2
# Haiti: 2
# Georgia: 2
# Equatorial Guinea: 1
# India: 1

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Country'] = label_encoder.fit_transform(df['Country'])
df.head()
# Out:
#    Country  Year      Status  Life expectancy   Adult Mortality  \
# 1        0  2014  Developing              59.9            271.0
# 3        0  2012  Developing              59.5            272.0
# 4        0  2011  Developing              59.2            275.0
# 5        0  2010  Developing              58.8            279.0
# 6        0  2009  Developing              58.6            281.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 1             64     0.01               73.523582         62.0       492  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
# 5             74     0.01               79.679367         66.0      1989  ...
# 6             77     0.01               56.762217         63.0      2861  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 1   58.0               8.18         62.0        0.1  612.696514
# 3   67.0               8.52         67.0        0.1  669.959000
# 4   68.0               7.87         68.0        0.1   63.537231
# 5   66.0               9.20         66.0        0.1  553.328940
# 6   63.0               9.42         63.0        0.1  445.893298
#
#    Population (in 100K)   thinness  1-19 years   thinness 5-9 years  \
# 1                  3.28                   17.5                 17.5
# 3                 36.97                   17.9                 18.0
# 4                 29.79                   18.2                 18.2
# 5                 28.83                   18.4                 18.4
# 6                  2.84                   18.6                 18.7
#
#    Income composition of resources  Schooling
# 1                            0.476       10.0
# 3                            0.463        9.8
# 4                            0.454        9.5
# 5                            0.448        9.2
# 6                            0.434        8.9
#
# [5 rows x 22 columns]

# %%
label_encoder = LabelEncoder()
df['Status'] = label_encoder.fit_transform(df['Status'])
df.head()
# Out:
#    Country  Year  Status  Life expectancy   Adult Mortality  infant deaths  \
# 1        0  2014       1              59.9            271.0             64
# 3        0  2012       1              59.5            272.0             69
# 4        0  2011       1              59.2            275.0             71
# 5        0  2010       1              58.8            279.0             74
# 6        0  2009       1              58.6            281.0             77
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 1     0.01               73.523582         62.0       492  ...   58.0
# 3     0.01               78.184215         67.0      2787  ...   67.0
# 4     0.01                7.097109         68.0      3013  ...   68.0
# 5     0.01               79.679367         66.0      1989  ...   66.0
# 6     0.01               56.762217         63.0      2861  ...   63.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 1               8.18         62.0        0.1  612.696514
# 3               8.52         67.0        0.1  669.959000
# 4               7.87         68.0        0.1   63.537231
# 5               9.20         66.0        0.1  553.328940
# 6               9.42         63.0        0.1  445.893298
#
#    Population (in 100K)   thinness  1-19 years   thinness 5-9 years  \
# 1                  3.28                   17.5                 17.5
# 3                 36.97                   17.9                 18.0
# 4                 29.79                   18.2                 18.2
# 5                 28.83                   18.4                 18.4
# 6                  2.84                   18.6                 18.7
#
#    Income composition of resources  Schooling
# 1                            0.476       10.0
# 3                            0.463        9.8
# 4                            0.454        9.5
# 5                            0.448        9.2
# 6                            0.434        8.9
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (1319, 22)

# %%
from sklearn.linear_model import LinearRegression

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population (in 100K)',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
y=df['Life expectancy ']
y.head()
# Out:
# 1    59.9
# 3    59.5
# 4    59.2
# 5    58.8
# 6    58.6
# Name: Life expectancy , dtype: float64

# %%
X=df.drop(['Life expectancy '],axis=1)
X.shape
# Out:
# (1319, 21)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (1055, 21)

# %%
X_test.shape
# Out:
# (264, 21)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-2.60936470e-03, -1.06471018e-01, -7.56647291e-01, -1.65421249e-02,
#         1.00223308e-01, -1.34003973e-01,  1.57025735e-04, -3.88958069e-03,
#        -1.35233204e-05,  4.71717811e-02, -7.43092885e-02,  9.44637631e-03,
#         2.42497655e-02,  1.61300215e-02, -4.51208415e-01,  4.22805896e-05,
#        -2.39884480e-03, -1.01889940e-01,  5.48473277e-03,  1.00740038e+01,
#         8.19289288e-01])

# %%
model.intercept_
# Out:
# 268.1938560941494

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([73.66657201, 73.5113115 , 70.12442261, 74.72472958, 61.52608409,
#        67.69877328, 76.96559836, 62.86693422, 59.74811202, 71.88236033,
#        79.38300986, 71.39004157, 68.73609445, 66.10513342, 66.64123168,
#        73.92837298, 74.17535925, 73.74812579, 69.35272174, 66.99226276,
#        61.84675761, 60.63182244, 69.99005014, 51.45455339, 53.35991648,
#        73.58139739, 67.00836385, 71.2278468 , 68.08869637, 60.07279444,
#        73.94056402, 69.919822  , 70.06309248, 71.27059923, 69.22514389,
#        84.0675954 , 70.85105061, 67.29495677, 57.78763328, 61.23908879,
#        76.49681231, 61.53421847, 74.02639815, 79.79215152, 69.93517217,
#        60.09952965, 78.45942578, 70.50405602, 63.74423627, 80.01151112,
#        72.3550503 , 70.84319149, 69.03311672, 52.88783212, 60.19817167,
#        71.6281014 , 72.07898593, 66.51177084, 52.35713481, 61.92467681,
#        67.40813596, 68.80442858, 73.62661276, 63.90553345, 68.12564707,
#        78.60444065, 82.8388107 , 71.08812469, 72.17364303, 72.46091282,
#        67.42745824, 63.34426185, 56.2834539 , 59.65887096, 59.59141472,
#        65.74831397, 77.21821699, 64.11104973, 62.03254039, 55.64723668,
#        70.92445929, 75.71063193, 79.93066091, 48.1872425 , 79.04852797,
#        70.91250214, 66.97962336, 75.12254653, 73.46439199, 64.34129926,
#        61.42871017, 76.26734879, 71.71125641, 75.82102955, 71.25650886,
#        53.27524014, 74.80789661, 76.57962944, 64.88524889, 76.63575778,
#        72.09314723, 60.66610342, 72.92377508, 65.07684811, 70.5183557 ,
#        60.44157093, 65.6063643 , 69.32894061, 79.01914762, 48.99340005,
#        70.91123054, 74.94960034, 77.1286676 , 76.70356429, 56.5719999 ,
#        70.04510005, 76.21786944, 63.61903734, 70.57817245, 77.80426094,
#        71.85687592, 62.04851702, 45.66153941, 71.79257052, 71.40213039,
#        42.25518912, 74.7409213 , 77.16798498, 69.20992385, 65.13618087,
#        71.28211149, 68.5467199 , 67.02160334, 75.87560028, 79.65842883,
#        75.03276392, 73.93435526, 37.77053852, 71.22426902, 36.92007828,
#        62.97853256, 54.60572326, 74.01821631, 75.45726188, 69.01285965,
#        70.21868422, 68.11225632, 60.91844159, 56.60696941, 54.0252627 ,
#        78.28078523, 57.60564735, 75.02151947, 56.66571087, 73.40073189,
#        67.66312913, 76.65566785, 68.46724363, 76.45115643, 67.84747676,
#        73.56890862, 67.7860138 , 59.94816341, 76.23228636, 76.80840761,
#        88.0170642 , 72.19668128, 71.72483032, 74.6606342 , 75.46380968,
#        63.63243644, 80.62503429, 64.28473005, 70.66964925, 72.71651009,
#        62.22311385, 71.04519378, 75.92839792, 62.80256924, 63.63585004,
#        70.26133649, 61.534719  , 73.55992787, 68.35606925, 59.53901448,
#        72.03424729, 71.0938839 , 73.13289387, 46.20696484, 61.5206024 ,
#        73.41024911, 63.51864007, 54.21666655, 63.12101103, 73.00626928,
#        79.0269449 , 76.48913183, 63.33309683, 72.66843375, 64.67162967,
#        65.73152461, 55.47785225, 62.22894465, 67.09978118, 65.63414549,
#        76.12238178, 75.27313406, 64.21900422, 73.26221738, 66.91541989,
#        68.41903878, 67.04951975, 68.87727691, 66.21628142, 70.29624005,
#        80.27268773, 59.04060134, 73.16265223, 74.88056074, 73.21874246,
#        69.37023252, 60.90222883, 76.38529169, 77.68674375, 72.07072245,
#        80.71660366, 73.36834646, 48.85816046, 64.40795731, 71.5522032 ,
#        70.29803702, 72.33006485, 66.28615198, 77.49717458, 59.57763228,
#        74.52758821, 51.99532596, 76.30418337, 36.92447607, 76.3902979 ,
#        49.04140944, 72.34607024, 73.17448982, 71.39275457, 55.79064553,
#        68.44079962, 69.22470552, 59.64798414, 60.12809069, 64.48823121,
#        49.96085979, 67.0100433 , 71.04477314, 59.00807415, 64.66587592,
#        64.3459856 , 64.84905361, 67.93365983, 73.79186951, 72.39580582,
#        54.11994047, 54.95566081, 69.12392682, 70.35413487])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
mse
# Out:
# 13.725901006918571

# %%
print(f"Model Coefficients: {model.coef_}")
print(f"Model Intercept: {model.intercept_}")
print(f"Mean Squared Error: {mse}")
# Out:
# Model Coefficients: [-2.60936470e-03 -1.06471018e-01 -7.56647291e-01 -1.65421249e-02
#   1.00223308e-01 -1.34003973e-01  1.57025735e-04 -3.88958069e-03
#  -1.35233204e-05  4.71717811e-02 -7.43092885e-02  9.44637631e-03
#   2.42497655e-02  1.61300215e-02 -4.51208415e-01  4.22805896e-05
#  -2.39884480e-03 -1.01889940e-01  5.48473277e-03  1.00740038e+01
#   8.19289288e-01]
# Model Intercept: 268.1938560941494
# Mean Squared Error: 13.725901006918571

# %%
df.to_csv('cleaned_dataframe.csv',index=False)

# %%
X_train.to_csv('X_train3.csv', index=False)
X_test.to_csv('X_test3.csv', index=False)
y_train.to_csv('y_train3.csv', index=False)
y_test.to_csv('y_test3.csv', index=False)
