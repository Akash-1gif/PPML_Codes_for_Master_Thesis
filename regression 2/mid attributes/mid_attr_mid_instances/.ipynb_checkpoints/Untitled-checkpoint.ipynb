# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X_train=pd.read_csv('X_train2.csv')
X_test=pd.read_csv('X_test2.csv')
y_train=pd.read_csv('y_train2.csv')
y_test=pd.read_csv('y_test2.csv')

# %%
X_train.head()
# Out:
#    Country  Year  Status  Adult Mortality  infant deaths  Alcohol  \
# 0       20  2008       1             35.0             23     4.33
# 1        8  2006       1            154.0              6     0.85
# 2        7  2003       0             88.0              0    12.20
# 3      126  2006       1            117.0              1     6.58
# 4        6  2002       0             73.0              1     9.84
#
#    percentage expenditure          GDP  Population (in 100K)  \
# 0               15.994152   196.247263                 82.12
# 1              105.633726  2473.857760                  8.48
# 2              504.430874  3212.935500                 81.21
# 3             1712.225506  5877.876780                  3.33
# 4               46.387182   281.817630                  1.97
#
#    Income composition of resources  Schooling  under-five deaths
# 0                            0.319        7.9                  35
# 1                            0.682       10.7                   7
# 2                            0.837       14.7                   0
# 3                            0.756       15.2                   1
# 4                            0.902       20.1                   2

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
y_test=y_test.to_numpy()

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 24.630310523121693

# %%
model.coef_
# Out:
# array([[-4.23009513e-03,  3.61931934e-02, -1.63356187e+00,
#         -2.54019029e-02,  4.88483368e-01, -5.58968269e-02,
#          3.62508600e-05,  5.01253646e-05,  1.76892743e-03,
#          1.07952149e+01,  5.25274839e-01, -4.17816138e-01]])

# %%
model.intercept_
# Out:
# array([-9.72562099])

# %%
import joblib
joblib.dump((model.coef_,model.coef_,y_pred),'variables_sklearn.pkl')
# Out:
# ['variables_sklearn.pkl']
