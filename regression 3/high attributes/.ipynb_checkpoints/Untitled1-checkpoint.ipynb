# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
df.dropna(inplace=True)

# %%
upper_threshold = df['Population'].quantile(0.90)
lower_threshold = df['Population'].quantile(0.10)

# Filter the DataFrame to remove the top 5% and bottom 5% rows based on the Population column
df_filtered = df[(df['Population'] <= upper_threshold) & (df['Population'] >= lower_threshold)]

# Display the filtered DataFrame
df_filtered.shape
# Out:
# (1319, 22)

# %%
df_filtered['Population'].max()
# Out:
# 29759989.0

# %%
df_filtered['Population'].min()
# Out:
# 25885.0

# %%
df_filtered['Population'].median()
# Out:
# 1419631.0

# %%
df_filtered['Population'].mean()
# Out:
# 4314016.684601971

# %%
df_filtered['Population']=df_filtered['Population']/100000
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13700\969936016.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Population']=df_filtered['Population']/100000

# %%
df_filtered['Population'].max()
# Out:
# 297.59989

# %%
df_filtered['Population'].min()
# Out:
# 0.25885

# %%
df_filtered.rename(columns={'Population': 'Population (in 100K)'}, inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13700\2902226852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.rename(columns={'Population': 'Population (in 100K)'}, inplace=True)

# %%
df_filtered
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 1     Afghanistan  2014  Developing              59.9            271.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# 5     Afghanistan  2010  Developing              58.8            279.0
# 6     Afghanistan  2009  Developing              58.6            281.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 1                64     0.01               73.523582         62.0       492
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# 5                74     0.01               79.679367         66.0      1989
# 6                77     0.01               56.762217         63.0      2861
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# 5     ...   66.0               9.20         66.0        0.1  553.328940
# 6     ...   63.0               9.42         63.0        0.1  445.893298
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population (in 100K)   thinness  1-19 years   thinness 5-9 years  \
# 1                  3.27582                   17.5                 17.5
# 3                 36.96958                   17.9                 18.0
# 4                 29.78599                   18.2                 18.2
# 5                 28.83167                   18.4                 18.4
# 6                  2.84331                   18.6                 18.7
# ...                    ...                    ...                  ...
# 2933             127.77511                    9.4                  9.4
# 2934             126.33897                    9.8                  9.9
# 2935               1.25525                    1.2                  1.3
# 2936             123.66165                    1.6                  1.7
# 2937             122.22251                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 1                               0.476       10.0
# 3                               0.463        9.8
# 4                               0.454        9.5
# 5                               0.448        9.2
# 6                               0.434        8.9
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [1319 rows x 22 columns]

# %%
df_filtered['Population (in 100K)'] = df_filtered['Population (in 100K)'].round(2)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13700\1150859451.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Population (in 100K)'] = df_filtered['Population (in 100K)'].round(2)

# %%
df_filtered.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 1  Afghanistan  2014  Developing              59.9            271.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
# 6  Afghanistan  2009  Developing              58.6            281.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 1             64     0.01               73.523582         62.0       492  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
# 5             74     0.01               79.679367         66.0      1989  ...
# 6             77     0.01               56.762217         63.0      2861  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 1   58.0               8.18         62.0        0.1  612.696514
# 3   67.0               8.52         67.0        0.1  669.959000
# 4   68.0               7.87         68.0        0.1   63.537231
# 5   66.0               9.20         66.0        0.1  553.328940
# 6   63.0               9.42         63.0        0.1  445.893298
#
#    Population (in 100K)   thinness  1-19 years   thinness 5-9 years  \
# 1                  3.28                   17.5                 17.5
# 3                 36.97                   17.9                 18.0
# 4                 29.79                   18.2                 18.2
# 5                 28.83                   18.4                 18.4
# 6                  2.84                   18.6                 18.7
#
#    Income composition of resources  Schooling
# 1                            0.476       10.0
# 3                            0.463        9.8
# 4                            0.454        9.5
# 5                            0.448        9.2
# 6                            0.434        8.9
#
# [5 rows x 22 columns]

# %%
df=df_filtered

# %%
df.shape
# Out:
# (1319, 22)

# %%
v=df['Country'].value_counts()

# %%
print(v)
# Out:
# Country
# Zimbabwe             15
# Belize               15
# Fiji                 15
# Honduras             15
# Jordan               15
#                      ..
# Ethiopia              2
# Haiti                 2
# Georgia               2
# Equatorial Guinea     1
# India                 1
# Name: count, Length: 131, dtype: int64

# %%
for i in v:
    print(i)
# Out:
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 6
# 6
# 6
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 4
# 4
# 4
# 3
# 2
# 2
# 2
# 1
# 1

# %%
# Get the value counts of the Country column
country_counts = df['Country'].value_counts()

# Print each country and its count
for country, count in country_counts.items():
    print(f'{country}: {count}')
# Out:
# Zimbabwe: 15
# Belize: 15
# Fiji: 15
# Honduras: 15
# Jordan: 15
# Lebanon: 15
# Bulgaria: 15
# Lithuania: 15
# Botswana: 15
# Costa Rica: 15
# Mongolia: 15
# Malaysia: 15
# Austria: 15
# Papua New Guinea: 15
# Belarus: 15
# Solomon Islands: 15
# Mozambique: 14
# Kazakhstan: 14
# Ecuador: 14
# El Salvador: 14
# Uruguay: 14
# Tunisia: 14
# Latvia: 14
# Albania: 14
# Romania: 14
# Panama: 14
# Luxembourg: 14
# Nicaragua: 14
# Dominican Republic: 14
# Afghanistan: 14
# Belgium: 14
# Armenia: 14
# Uzbekistan: 13
# Mauritius: 13
# Guyana: 13
# Madagascar: 13
# Swaziland: 13
# Malawi: 13
# Rwanda: 13
# Ghana: 13
# Portugal: 12
# Azerbaijan: 12
# Mexico: 12
# Nepal: 12
# Greece: 12
# Bhutan: 12
# Jamaica: 12
# Paraguay: 12
# Peru: 12
# Tajikistan: 12
# Ukraine: 12
# Cyprus: 12
# Mali: 11
# Burundi: 11
# Comoros: 11
# Australia: 11
# Malta: 11
# Serbia: 11
# Trinidad and Tobago: 11
# Turkmenistan: 11
# Cabo Verde: 11
# Benin: 11
# China: 11
# Eritrea: 10
# Mauritania: 10
# Zambia: 10
# Lesotho: 10
# Seychelles: 10
# Bosnia and Herzegovina: 10
# Guatemala: 10
# Senegal: 10
# Samoa: 10
# Poland: 10
# Germany: 9
# Gabon: 9
# France: 9
# Cameroon: 9
# Russian Federation: 9
# Estonia: 9
# Chile: 9
# Turkey: 9
# Vanuatu: 9
# Bangladesh: 9
# Philippines: 9
# Indonesia: 9
# Burkina Faso: 9
# Kenya: 9
# Cambodia: 8
# Thailand: 8
# Uganda: 8
# Brazil: 8
# Angola: 8
# Sierra Leone: 8
# Suriname: 8
# Syrian Arab Republic: 8
# Morocco: 8
# Guinea: 8
# Italy: 8
# Iraq: 7
# Liberia: 7
# Argentina: 7
# Spain: 7
# Togo: 7
# Canada: 7
# Sao Tome and Principe: 7
# Djibouti: 7
# Croatia: 7
# Montenegro: 7
# Pakistan: 7
# Nigeria: 7
# Chad: 7
# Central African Republic: 6
# Guinea-Bissau: 6
# Niger: 6
# Israel: 5
# Timor-Leste: 5
# Myanmar: 5
# South Africa: 5
# Namibia: 5
# Ireland: 5
# Colombia: 5
# Kiribati: 5
# Sweden: 4
# Algeria: 4
# Netherlands: 4
# Tonga: 3
# Ethiopia: 2
# Haiti: 2
# Georgia: 2
# Equatorial Guinea: 1
# India: 1

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Country'] = label_encoder.fit_transform(df['Country'])
df.head()
# Out:
#    Country  Year      Status  Life expectancy   Adult Mortality  \
# 1        0  2014  Developing              59.9            271.0
# 3        0  2012  Developing              59.5            272.0
# 4        0  2011  Developing              59.2            275.0
# 5        0  2010  Developing              58.8            279.0
# 6        0  2009  Developing              58.6            281.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 1             64     0.01               73.523582         62.0       492  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
# 5             74     0.01               79.679367         66.0      1989  ...
# 6             77     0.01               56.762217         63.0      2861  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 1   58.0               8.18         62.0        0.1  612.696514
# 3   67.0               8.52         67.0        0.1  669.959000
# 4   68.0               7.87         68.0        0.1   63.537231
# 5   66.0               9.20         66.0        0.1  553.328940
# 6   63.0               9.42         63.0        0.1  445.893298
#
#    Population (in 100K)   thinness  1-19 years   thinness 5-9 years  \
# 1                  3.28                   17.5                 17.5
# 3                 36.97                   17.9                 18.0
# 4                 29.79                   18.2                 18.2
# 5                 28.83                   18.4                 18.4
# 6                  2.84                   18.6                 18.7
#
#    Income composition of resources  Schooling
# 1                            0.476       10.0
# 3                            0.463        9.8
# 4                            0.454        9.5
# 5                            0.448        9.2
# 6                            0.434        8.9
#
# [5 rows x 22 columns]

# %%
label_encoder = LabelEncoder()
df['Status'] = label_encoder.fit_transform(df['Status'])
df.head()
# Out:
#    Country  Year  Status  Life expectancy   Adult Mortality  infant deaths  \
# 1        0  2014       1              59.9            271.0             64
# 3        0  2012       1              59.5            272.0             69
# 4        0  2011       1              59.2            275.0             71
# 5        0  2010       1              58.8            279.0             74
# 6        0  2009       1              58.6            281.0             77
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 1     0.01               73.523582         62.0       492  ...   58.0
# 3     0.01               78.184215         67.0      2787  ...   67.0
# 4     0.01                7.097109         68.0      3013  ...   68.0
# 5     0.01               79.679367         66.0      1989  ...   66.0
# 6     0.01               56.762217         63.0      2861  ...   63.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 1               8.18         62.0        0.1  612.696514
# 3               8.52         67.0        0.1  669.959000
# 4               7.87         68.0        0.1   63.537231
# 5               9.20         66.0        0.1  553.328940
# 6               9.42         63.0        0.1  445.893298
#
#    Population (in 100K)   thinness  1-19 years   thinness 5-9 years  \
# 1                  3.28                   17.5                 17.5
# 3                 36.97                   17.9                 18.0
# 4                 29.79                   18.2                 18.2
# 5                 28.83                   18.4                 18.4
# 6                  2.84                   18.6                 18.7
#
#    Income composition of resources  Schooling
# 1                            0.476       10.0
# 3                            0.463        9.8
# 4                            0.454        9.5
# 5                            0.448        9.2
# 6                            0.434        8.9
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (1319, 22)

# %%
from sklearn.linear_model import LinearRegression

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population (in 100K)',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
y=df['Life expectancy ']
y.head()
# Out:
# 1    59.9
# 3    59.5
# 4    59.2
# 5    58.8
# 6    58.6
# Name: Life expectancy , dtype: float64

# %%
X=df.drop(['Life expectancy '],axis=1)
X.shape
# Out:
# (1319, 21)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=69)

# %%
X_train.shape
# Out:
# (1055, 21)

# %%
X_test.shape
# Out:
# (264, 21)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 2.00047368e-03, -9.89433796e-02, -8.63136806e-01, -1.50948566e-02,
#         1.04596170e-01, -1.26595833e-01,  3.76414061e-04, -8.82341933e-03,
#        -2.00347213e-05,  4.16558316e-02, -7.71707138e-02,  4.39284990e-03,
#         8.52351637e-02,  2.41472428e-02, -4.47085448e-01,  4.82002453e-06,
#        -1.61755189e-03, -7.17114757e-02, -6.44202679e-02,  1.13826481e+01,
#         7.60173176e-01])

# %%
model.intercept_
# Out:
# 252.6743846666982

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([60.36709728, 51.94314579, 71.00542914, 61.37328869, 71.14582253,
#        55.19366194, 62.22452836, 54.38082138, 59.77877951, 71.00419713,
#        70.58474154, 74.76988065, 67.98306467, 76.55550325, 60.86180731,
#        72.41408906, 79.6833773 , 72.11903873, 76.8958593 , 76.86003424,
#        65.13594366, 78.74803802, 67.65694859, 59.57714056, 58.3027039 ,
#        66.47822886, 76.56667995, 78.89444573, 74.28807578, 55.70266873,
#        71.67179384, 72.75510173, 69.80442254, 70.46894282, 72.34347527,
#        74.91698022, 53.26163241, 71.85542613, 60.53819712, 64.30845419,
#        71.39865529, 73.1402281 , 48.08839051, 71.92704364, 80.44323726,
#        77.48580576, 70.96350805, 60.67441993, 66.63962495, 68.79121418,
#        65.77259182, 74.2386487 , 61.5848575 , 72.71300864, 71.51948681,
#        66.98381147, 76.27403499, 69.80332627, 78.89605403, 67.9388866 ,
#        78.35677221, 60.9903223 , 73.10602871, 73.62827844, 69.13227304,
#        69.44101708, 60.43180822, 63.65955983, 62.04257533, 61.62801733,
#        63.89463842, 72.01657223, 57.15473314, 72.25315338, 66.84495622,
#        68.38639545, 80.20661118, 66.99869724, 73.5221988 , 71.49529688,
#        47.81208179, 70.88183623, 69.53342901, 60.30916593, 62.06476284,
#        71.65820884, 75.52548163, 57.47831199, 65.33693487, 61.62185943,
#        56.01805493, 60.94300263, 73.34798527, 73.62590946, 59.10600321,
#        50.3290829 , 68.346512  , 60.36185811, 68.52667211, 76.40758271,
#        61.10554074, 66.02336236, 73.39271404, 56.60219366, 66.66163708,
#        70.78452166, 51.85024781, 64.85232931, 64.58501983, 63.59259671,
#        71.3316239 , 60.91550015, 75.7992461 , 72.10366105, 65.91557099,
#        70.25728819, 67.31799719, 74.39259382, 59.88938226, 64.22578395,
#        71.99657986, 61.7899912 , 74.23289871, 85.16416211, 75.46980831,
#        80.16085736, 78.43955162, 71.66610203, 62.49717927, 69.98390783,
#        66.80412199, 60.26087358, 79.61178541, 72.11905791, 71.04535136,
#        76.7462305 , 69.63905285, 69.67512171, 56.2682356 , 82.61126313,
#        70.68459045, 66.48283   , 76.31950973, 60.13249491, 65.72966251,
#        68.54144376, 55.46036931, 72.42291832, 84.5840481 , 67.50318788,
#        71.62478213, 74.24362274, 67.82736828, 71.58560926, 65.47478695,
#        58.62306459, 43.3576755 , 81.27516454, 59.17377122, 72.78128878,
#        70.36448163, 67.17116218, 69.34236929, 75.72677922, 73.92108221,
#        42.82943699, 77.01679495, 55.96265542, 68.79657669, 78.1134503 ,
#        69.52554147, 76.76529211, 73.25030449, 73.11750853, 64.40287766,
#        71.94947653, 77.09218358, 68.45065829, 71.87934078, 60.55845705,
#        75.27754529, 67.69527625, 68.79086059, 72.75876059, 61.44520431,
#        72.67788359, 72.11029947, 63.85806344, 74.16039555, 74.54004737,
#        70.00804713, 72.91571621, 78.11884553, 71.67819293, 73.17358407,
#        69.2229193 , 74.22387932, 65.43500987, 64.39814808, 48.86491211,
#        58.09501668, 77.97171027, 64.48063618, 74.8634711 , 69.80049486,
#        52.17468626, 81.15709991, 49.38562102, 72.15901462, 60.03091199,
#        76.25102337, 77.69521904, 71.86624055, 74.02405948, 73.92287401,
#        73.51010123, 71.87848547, 77.08408726, 75.06523841, 71.51414142,
#        72.24109145, 66.13357293, 79.64951608, 79.68558151, 77.3238941 ,
#        71.11396266, 84.18920805, 69.67110709, 59.71776231, 69.54909563,
#        72.00816575, 66.82092588, 74.57362341, 55.9968906 , 73.70745846,
#        45.90416756, 72.67523496, 71.13337496, 69.61986466, 74.05038719,
#        64.08370532, 80.23233587, 74.01963888, 74.38355159, 76.85474963,
#        74.17261886, 72.64330937, 74.93550638, 73.78288408, 83.06114429,
#        74.1951726 , 65.65650654, 65.49865131, 71.15661482, 63.75009483,
#        63.19382971, 70.77458671, 77.03727479, 81.59630311, 70.65248066,
#        72.67098008, 78.04594448, 69.23932993, 77.95349397])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
mse
# Out:
# 16.63541940383327

# %%
print(f"Model Coefficients: {model.coef_}")
print(f"Model Intercept: {model.intercept_}")
print(f"Mean Squared Error: {mse}")
# Out:
# Model Coefficients: [ 2.00047368e-03 -9.89433796e-02 -8.63136806e-01 -1.50948566e-02
#   1.04596170e-01 -1.26595833e-01  3.76414061e-04 -8.82341933e-03
#  -2.00347213e-05  4.16558316e-02 -7.71707138e-02  4.39284990e-03
#   8.52351637e-02  2.41472428e-02 -4.47085448e-01  4.82002453e-06
#  -1.61755189e-03 -7.17114757e-02 -6.44202679e-02  1.13826481e+01
#   7.60173176e-01]
# Model Intercept: 252.6743846666982
# Mean Squared Error: 16.63541940383327

# %%
df.to_csv('cleaned_dataframe.csv',index=False)

# %%
X_train.to_csv('X_train3.csv', index=False)
X_test.to_csv('X_test3.csv', index=False)
y_train.to_csv('y_train3.csv', index=False)
y_test.to_csv('y_test3.csv', index=False)
