# %%
import matplotlib.pyplot as plt
import numpy as np

# Weights from manual model
weights_manual = np.array([ 0.28753635,  0.56852068, -0.14229739,  0.06995865,  0.13590936, -0.12930347,
                            0.03396643,  0.09281617,  0.01991624, -0.06060862,  0.30537194,  0.07022978,
                            0.09073586,  0.03398337,  0.15935749])

# Weights from sklearn model
weights_sklearn = np.array([ 0.32214527,  0.68597104, -0.10359398,  0.09137761,  0.22509405, -0.18547992,
                             0.08234119,  0.09215923, -0.03126306, -0.07810777,  0.25824565,  0.07067023,
                             0.08354257, -0.04280626,  0.17471094])

# Indices for the weights
indices = np.arange(len(weights_manual))

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(indices, weights_manual, label='Manual Weights', marker='o')
plt.plot(indices, weights_sklearn, label='Sklearn Weights', marker='x')
plt.xlabel('Weight Index')
plt.ylabel('Weight Value')
plt.title('Comparison of Weights from Manual Model and Sklearn Model')
plt.legend()
plt.grid(True)
plt.show()
