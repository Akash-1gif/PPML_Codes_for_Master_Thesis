# %%
# !pip install phe
# Out:
# Collecting phe
#   Downloading phe-1.5.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 579.6 kB/s eta 0:00:00
# Installing collected packages: phe
# Successfully installed phe-1.5.0

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from scipy.special import expit
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from phe import paillier
import time
import psutil
import os
from threading import Thread, Lock

# %%
# Load datasets
X_train = pd.read_csv('X_train3.csv').to_numpy()
X_test = pd.read_csv('X_test3.csv').to_numpy()
y_train = pd.read_csv('y_train3.csv').to_numpy().reshape(-1)
y_test = pd.read_csv('y_test3.csv').to_numpy().reshape(-1)

# %%
# Paillier key generation
public_key, private_key = paillier.generate_paillier_keypair()

# %%
# Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Lock for controlling CPU monitoring
monitor_lock = Lock()

# %%
# Function to handle encrypted multiplication at the edge device
def paillier_multiplication_edge(a, b):
    with monitor_lock:  # Acquire lock to exclude this part from CPU and RAM monitoring
        a = private_key.decrypt(a)
        a = round(a, 7)
        a = a * b
    return a

# %%
# Function to handle encrypted multiplication at the cloud
def paillier_multiplication_cloud(a, b):
    noise1 = 1
    noise2 = 2
    a = a + noise1
    sub_mass = (b * noise1) * (-1)
    sol = paillier_multiplication_edge(a, b)
    sol = sol + sub_mass
    return sol

# %%
# Function to apply the sigmoid function on encrypted data
def sigmoid(z):
    with monitor_lock:  # Acquire lock to exclude this part from CPU and RAM monitoring
        z = private_key.decrypt(z)
        z = expit(z)
        z = public_key.encrypt(z)
    return z

# %%
m, n = X_train.shape
weights = np.zeros(n)
bias = 0
learning_rate = 0.01

# %%
row=1
enc_X_train=[]
for i in X_train:
  row_x=[]
  for j in i:
    k=public_key.encrypt(j)
    row_x.append(k)
  enc_X_train.append(row_x)
  print(f"row {row} encrypted")
  row=row+1
enc_y_train = [public_key.encrypt(int(i)) for i in y_train]
# Out:
# row 1 encrypted
# row 2 encrypted
# row 3 encrypted
# row 4 encrypted
# row 5 encrypted
# row 6 encrypted
# row 7 encrypted
# row 8 encrypted
# row 9 encrypted
# row 10 encrypted
# row 11 encrypted
# row 12 encrypted
# row 13 encrypted
# row 14 encrypted
# row 15 encrypted
# row 16 encrypted
# row 17 encrypted
# row 18 encrypted
# row 19 encrypted
# row 20 encrypted
# row 21 encrypted
# row 22 encrypted
# row 23 encrypted
# row 24 encrypted
# row 25 encrypted
# row 26 encrypted
# row 27 encrypted
# row 28 encrypted
# row 29 encrypted
# row 30 encrypted
# row 31 encrypted
# row 32 encrypted
# row 33 encrypted
# row 34 encrypted
# row 35 encrypted
# row 36 encrypted
# row 37 encrypted
# row 38 encrypted
# row 39 encrypted
# row 40 encrypted
# row 41 encrypted
# row 42 encrypted
# row 43 encrypted
# row 44 encrypted
# row 45 encrypted
# row 46 encrypted
# row 47 encrypted
# row 48 encrypted
# row 49 encrypted
# row 50 encrypted
# row 51 encrypted
# row 52 encrypted
# row 53 encrypted
# row 54 encrypted
# row 55 encrypted
# row 56 encrypted
# row 57 encrypted
# row 58 encrypted
# row 59 encrypted
# row 60 encrypted
# row 61 encrypted
# row 62 encrypted
# row 995 encrypted
# row 996 encrypted
# row 997 encrypted
# row 998 encrypted
# row 999 encrypted
# row 1000 encrypted
# row 1001 encrypted
# row 1002 encrypted
# row 1003 encrypted
# row 1004 encrypted
# row 1005 encrypted
# row 1006 encrypted
# row 1007 encrypted
# row 1008 encrypted
# row 1009 encrypted
# row 1010 encrypted
# row 1011 encrypted
# row 1012 encrypted
# row 1013 encrypted
# row 1014 encrypted
# row 1015 encrypted
# row 1016 encrypted
# row 1017 encrypted
# row 1018 encrypted
# row 1019 encrypted
# row 1020 encrypted
# row 1021 encrypted
# row 1022 encrypted
# row 1023 encrypted
# row 1024 encrypted
# row 1025 encrypted
# row 1026 encrypted
# row 1027 encrypted
# row 1028 encrypted
# row 1029 encrypted
# row 1030 encrypted
# row 1031 encrypted
# row 1032 encrypted
# row 1033 encrypted
# row 1034 encrypted
# row 1035 encrypted
# row 1036 encrypted
# row 1037 encrypted
# row 1038 encrypted
# row 1039 encrypted
# row 1040 encrypted
# row 1041 encrypted
# row 1042 encrypted
# row 1043 encrypted
# row 1044 encrypted
# row 1045 encrypted
# row 1046 encrypted
# row 1047 encrypted
# row 1048 encrypted
# row 1049 encrypted
# row 1050 encrypted
# row 1051 encrypted
# row 1052 encrypted
# row 1053 encrypted
# row 1054 encrypted
# row 1055 encrypted
# row 1056 encrypted
# row 1057 encrypted
# row 1058 encrypted
# row 1059 encrypted
# row 1060 encrypted
# row 1061 encrypted
# row 1062 encrypted
# row 1063 encrypted
# row 1064 encrypted
# row 1065 encrypted
# row 1066 encrypted
# row 1067 encrypted
# row 1068 encrypted
# row 1069 encrypted
# row 1070 encrypted
# row 1071 encrypted
# row 1072 encrypted
# row 1073 encrypted
# row 1074 encrypted
# row 1075 encrypted
# row 1076 encrypted
# row 1077 encrypted
# row 1078 encrypted
# row 1079 encrypted
# row 1080 encrypted

# %%
# Function to monitor CPU and RAM usage
def get_cpu_and_ram_utilization(pid, duration):
    process = psutil.Process(pid)
    cpu_usages = []
    ram_usages = []
    start_time = time.time()
    while time.time() - start_time < duration:
        # with monitor_lock:
        cpu_usage = process.cpu_percent(interval=1)
        ram_usage = process.memory_percent()
        cpu_usages.append(cpu_usage)
        ram_usages.append(ram_usage)
        print(f"CPU utilization: {cpu_usage}% | RAM utilization: {ram_usage}%")
    total_cpu_usage = sum(cpu_usages)
    return total_cpu_usage, cpu_usages, ram_usages

# %%
pid = os.getpid()

# Duration to monitor CPU usage
monitor_duration = 30300

time.sleep(15)

# %%
results={}
# Logistic Regression SGD training function
def logistic_regression_sgd(X, y, n, learning_rate=0.01, epochs=3):
    train_time_start = time.time()
    weights = np.zeros(n)

    weights_enc = [public_key.encrypt(i) for i in weights]
    bias = 0
    bias_enc = public_key.encrypt(bias)

    for epoch in range(epochs):
        count=0
        indices = np.random.permutation(m)
        for i in indices:
            xi = enc_X_train[i]
            yi = enc_y_train[i]

            linear_output = sum(paillier_multiplication_cloud(i, j) for i, j in zip(xi, weights_enc))
            linear_output = linear_output + bias_enc
            y_pred = sigmoid(linear_output)
            db = y_pred + (yi * (-1))
            dw = [paillier_multiplication_cloud(i, db) for i in xi]

            for i in range(len(weights_enc)):
                weights_enc[i] = weights_enc[i] + (dw[i] * (-1) * learning_rate)
            bias_enc = bias_enc + (db * -1) * learning_rate
            print(f"epoch={epoch},iter={count} executed")
            count=count+1

    train_time_end = time.time()
    train_time = train_time_end - train_time_start

    results['train_time'] = train_time
    results['weights'] = weights_enc
    results['bias'] = bias_enc
    print(results['train_time'])

# %%
# Start the training thread
train_thread = Thread(target=logistic_regression_sgd, args=(enc_X_train, enc_y_train, n, learning_rate))
train_thread.start()

# Monitor CPU and RAM usage while training
total_cpu_usage, cpu_usages, ram_usages = get_cpu_and_ram_utilization(pid, monitor_duration)
train_thread.join()

print(f"Total CPU utilization over {monitor_duration} seconds: {total_cpu_usage}%")
print("CPU usage per second:", cpu_usages)
print("RAM usage per second:", ram_usages)

# Calculate total CPU resource consumption in 'CPU-seconds'
cpu_seconds = sum(cpu_usages) / 100
print(f"Total CPU resource consumption: {cpu_seconds} CPU-seconds")
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch=1,iter=271 executed
# CPU utilization: 100.2% | RAM utilization: 1.7765224078022883%
# CPU utilization: 104.8% | RAM utilization: 1.7765224078022883%
# CPU utilization: 131.3% | RAM utilization: 1.7765224078022883%
# CPU utilization: 100.0% | RAM utilization: 1.7765224078022883%
# CPU utilization: 97.3% | RAM utilization: 1.7765224078022883%
# CPU utilization: 96.5% | RAM utilization: 1.7765224078022883%
# epoch=1,iter=272 executed
# CPU utilization: 108.4% | RAM utilization: 1.7765224078022883%
# CPU utilization: 100.1% | RAM utilization: 1.7765224078022883%
# CPU utilization: 96.2% | RAM utilization: 1.7765224078022883%
# CPU utilization: 100.7% | RAM utilization: 1.7765224078022883%
# CPU utilization: 100.9% | RAM utilization: 1.7765224078022883%
# epoch=1,iter=273 executed
# CPU utilization: 100.3% | RAM utilization: 1.7765224078022883%
# CPU utilization: 99.8% | RAM utilization: 1.7765224078022883%
# CPU utilization: 101.9% | RAM utilization: 1.7765224078022883%
# CPU utilization: 98.8% | RAM utilization: 1.7765224078022883%
# CPU utilization: 96.2% | RAM utilization: 1.7765224078022883%
# CPU utilization: 95.4% | RAM utilization: 1.7765224078022883%
# epoch=1,iter=274 executed
# CPU utilization: 103.7% | RAM utilization: 1.7765224078022883%
# CPU utilization: 103.2% | RAM utilization: 1.7765224078022883%
# CPU utilization: 101.5% | RAM utilization: 1.7765224078022883%
# CPU utilization: 103.7% | RAM utilization: 1.7765224078022883%
# CPU utilization: 102.4% | RAM utilization: 1.7765224078022883%
# epoch=1,iter=275 executed
# CPU utilization: 99.7% | RAM utilization: 1.7765224078022883%
# CPU utilization: 106.2% | RAM utilization: 1.7765224078022883%
# CPU utilization: 99.0% | RAM utilization: 1.7765224078022883%
# CPU utilization: 97.7% | RAM utilization: 1.7765224078022883%
# CPU utilization: 97.2% | RAM utilization: 1.7765224078022883%
# CPU utilization: 97.4% | RAM utilization: 1.7765224078022883%
# epoch=1,iter=276 executed
# CPU utilization: 101.2% | RAM utilization: 1.7765224078022883%
# CPU utilization: 99.7% | RAM utilization: 1.7765224078022883%
# CPU utilization: 106.5% | RAM utilization: 1.7765224078022883%
# CPU utilization: 110.3% | RAM utilization: 1.7765224078022883%
# CPU utilization: 109.5% | RAM utilization: 1.7765224078022883%
# epoch=1,iter=277 executed
# CPU utilization: 95.0% | RAM utilization: 1.7765224078022883%
# CPU utilization: 91.9% | RAM utilization: 1.7765224078022883%
# CPU utilization: 101.0% | RAM utilization: 1.7765224078022883%
# CPU utilization: 98.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=278 executed
# CPU utilization: 105.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 91.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=279 executed
# CPU utilization: 112.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=280 executed
# CPU utilization: 104.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=281 executed
# CPU utilization: 104.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 103.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.5% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=282 executed
# CPU utilization: 112.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 111.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.8% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=283 executed
# CPU utilization: 98.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.7% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=284 executed
# CPU utilization: 105.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 109.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.3% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=285 executed
# CPU utilization: 95.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.3% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=286 executed
# CPU utilization: 105.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 89.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=287 executed
# CPU utilization: 93.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 88.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=288 executed
# CPU utilization: 101.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 91.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=289 executed
# CPU utilization: 97.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 109.3% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=290 executed
# CPU utilization: 105.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 90.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=291 executed
# CPU utilization: 95.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=292 executed
# CPU utilization: 101.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 110.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=293 executed
# CPU utilization: 98.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 142.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.3% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=294 executed
# CPU utilization: 104.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 110.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=295 executed
# CPU utilization: 96.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 92.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.1% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=296 executed
# CPU utilization: 107.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 132.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 91.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.5% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=297 executed
# CPU utilization: 107.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 107.8% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=298 executed
# CPU utilization: 99.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 109.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=299 executed
# CPU utilization: 99.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.3% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=300 executed
# CPU utilization: 102.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=301 executed
# CPU utilization: 104.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 90.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.6% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=302 executed
# CPU utilization: 105.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.8% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=303 executed
# CPU utilization: 99.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 107.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=304 executed
# CPU utilization: 103.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=305 executed
# CPU utilization: 95.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.5% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=306 executed
# CPU utilization: 101.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 89.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.6% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=307 executed
# CPU utilization: 104.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=308 executed
# CPU utilization: 100.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=309 executed
# CPU utilization: 104.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 110.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.8% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=310 executed
# CPU utilization: 95.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=311 executed
# CPU utilization: 97.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 108.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=312 executed
# CPU utilization: 93.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=313 executed
# CPU utilization: 106.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=314 executed
# CPU utilization: 95.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 109.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=315 executed
# CPU utilization: 105.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=316 executed
# CPU utilization: 96.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=317 executed
# CPU utilization: 98.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 112.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=318 executed
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.6% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=319 executed
# CPU utilization: 107.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 92.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.3% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=320 executed
# CPU utilization: 102.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.1% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=321 executed
# CPU utilization: 105.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=322 executed
# CPU utilization: 100.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 91.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=323 executed
# CPU utilization: 99.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.2% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=324 executed
# CPU utilization: 105.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 92.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.5% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=325 executed
# CPU utilization: 99.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=326 executed
# CPU utilization: 101.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 110.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=327 executed
# CPU utilization: 106.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 93.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 107.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=328 executed
# CPU utilization: 98.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 93.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.6% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=329 executed
# CPU utilization: 100.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 103.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 103.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.1% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=330 executed
# CPU utilization: 106.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 88.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=331 executed
# CPU utilization: 104.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 91.7% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=332 executed
# CPU utilization: 102.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 110.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.7% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=333 executed
# CPU utilization: 97.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 107.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=334 executed
# CPU utilization: 96.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=335 executed
# CPU utilization: 93.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=336 executed
# CPU utilization: 111.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.2% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=337 executed
# CPU utilization: 95.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.5% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=338 executed
# CPU utilization: 103.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.2% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=339 executed
# CPU utilization: 100.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.3% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=340 executed
# CPU utilization: 105.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.7% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=341 executed
# CPU utilization: 99.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.2% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=342 executed
# CPU utilization: 111.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 89.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.6% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=343 executed
# CPU utilization: 99.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 90.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 93.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=344 executed
# CPU utilization: 108.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.6% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=345 executed
# CPU utilization: 104.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.1% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=346 executed
# CPU utilization: 88.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.2% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=347 executed
# CPU utilization: 105.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 110.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 107.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=348 executed
# CPU utilization: 104.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 91.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 108.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 103.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=349 executed
# CPU utilization: 105.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 111.7% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=350 executed
# CPU utilization: 99.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.1% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=351 executed
# CPU utilization: 96.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 109.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 92.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=352 executed
# CPU utilization: 97.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.8% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=353 executed
# CPU utilization: 97.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 112.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 110.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 110.6% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=354 executed
# CPU utilization: 94.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.1% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=355 executed
# CPU utilization: 99.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 108.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 109.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.5% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=356 executed
# CPU utilization: 93.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 111.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.6% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=357 executed
# CPU utilization: 99.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 93.8% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=358 executed
# CPU utilization: 96.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 113.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.1% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=359 executed
# CPU utilization: 105.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 109.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 111.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.8% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=360 executed
# CPU utilization: 97.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=361 executed
# CPU utilization: 94.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 90.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.3% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=362 executed
# CPU utilization: 95.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 107.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 92.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 112.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.6% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=363 executed
# CPU utilization: 103.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 88.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 86.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=364 executed
# CPU utilization: 99.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=365 executed
# CPU utilization: 99.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 108.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=366 executed
# CPU utilization: 100.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.2% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=367 executed
# CPU utilization: 101.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=368 executed
# CPU utilization: 107.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=369 executed
# CPU utilization: 99.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 89.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.7% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=370 executed
# CPU utilization: 104.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.1% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=371 executed
# CPU utilization: 99.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 93.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.1% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=372 executed
# CPU utilization: 94.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 88.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 108.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=373 executed
# CPU utilization: 106.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.7% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=374 executed
# CPU utilization: 104.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 91.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 103.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=375 executed
# CPU utilization: 96.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.7% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=376 executed
# CPU utilization: 104.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=377 executed
# CPU utilization: 96.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 112.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.4% | RAM utilization: 1.7785087950304206%epoch=1,iter=378 executed
#
# CPU utilization: 102.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 93.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 90.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=379 executed
# CPU utilization: 95.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 133.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 107.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.0% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=380 executed
# CPU utilization: 96.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=381 executed
# CPU utilization: 96.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.3% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=382 executed
# CPU utilization: 99.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.1% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=383 executed
# CPU utilization: 104.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 89.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 91.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=384 executed
# CPU utilization: 99.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 87.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 90.2% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=385 executed
# CPU utilization: 106.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 87.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=386 executed
# CPU utilization: 103.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.3% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=387 executed
# CPU utilization: 100.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 89.3% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=388 executed
# CPU utilization: 107.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 107.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 91.7% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.4% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=389 executed
# CPU utilization: 101.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.7% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=390 executed
# CPU utilization: 108.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.7% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=391 executed
# CPU utilization: 91.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 101.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 106.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 104.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.5% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=392 executed
# CPU utilization: 110.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.9% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.7% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=393 executed
# CPU utilization: 105.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 100.3% | RAM utilization: 1.7785087950304206%
# CPU utilization: 105.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 94.2% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=394 executed
# CPU utilization: 106.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 93.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 89.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 108.2% | RAM utilization: 1.7785087950304206%
# CPU utilization: 103.9% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=395 executed
# CPU utilization: 103.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 99.6% | RAM utilization: 1.7785087950304206%
# CPU utilization: 102.0% | RAM utilization: 1.7785087950304206%
# CPU utilization: 95.8% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=396 executed
# CPU utilization: 110.8% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.4% | RAM utilization: 1.7785087950304206%
# CPU utilization: 97.1% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 109.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 98.5% | RAM utilization: 1.7785087950304206%
# epoch=1,iter=397 executed
# CPU utilization: 95.5% | RAM utilization: 1.7785087950304206%
# CPU utilization: 96.4% | RAM utilization: 1.7785087950304206%
# ...
# CPU utilization: 91.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 95.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 102.0% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=976 executed
# CPU utilization: 100.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 94.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 105.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 102.8% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=977 executed
# CPU utilization: 100.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 111.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 95.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.4% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=978 executed
# CPU utilization: 107.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 102.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.6% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=979 executed
# CPU utilization: 99.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 105.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 92.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 95.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 105.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 91.0% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=980 executed
# CPU utilization: 96.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 107.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 104.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.7% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=981 executed
# CPU utilization: 103.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.4% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=982 executed
# CPU utilization: 100.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 108.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 105.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 94.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 87.5% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=983 executed
# CPU utilization: 100.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 104.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.4% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=984 executed
# CPU utilization: 110.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.8% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=985 executed
# CPU utilization: 95.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 93.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 104.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 94.2% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=986 executed
# CPU utilization: 99.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 92.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 103.3% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=987 executed
# CPU utilization: 93.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 103.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 95.9% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=988 executed
# CPU utilization: 111.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 107.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.4% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=989 executed
# CPU utilization: 94.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 105.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 104.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.6% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=990 executed
# CPU utilization: 104.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 90.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.9% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=991 executed
# CPU utilization: 97.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 89.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 103.1% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=992 executed
# CPU utilization: 88.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 95.7% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=993 executed
# CPU utilization: 98.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 105.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 105.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.4% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=994 executed
# CPU utilization: 104.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.7% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=995 executed
# CPU utilization: 98.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 113.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 95.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.8% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=996 executed
# CPU utilization: 98.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 111.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 110.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 95.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 95.8% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=997 executed
# CPU utilization: 104.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 105.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 110.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.7% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=998 executed
# CPU utilization: 98.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.9% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=999 executed
# CPU utilization: 98.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 90.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 104.8% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1000 executed
# CPU utilization: 111.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 103.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 95.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 102.6% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1001 executed
# CPU utilization: 91.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 105.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 104.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.2% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1002 executed
# CPU utilization: 100.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 92.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.0% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1003 executed
# CPU utilization: 112.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 103.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 94.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 94.3% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1004 executed
# CPU utilization: 102.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 93.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.4% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1005 executed
# CPU utilization: 93.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 93.4% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1006 executed
# CPU utilization: 100.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 95.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 109.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.2% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1007 executed
# CPU utilization: 104.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 94.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.5% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1008 executed
# CPU utilization: 100.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 94.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 107.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 102.2% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1009 executed
# CPU utilization: 111.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.2% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1010 executed
# CPU utilization: 103.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 95.9% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.5% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1011 executed
# CPU utilization: 110.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 90.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.1% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1012 executed
# CPU utilization: 95.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 96.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 105.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 105.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.8% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1013 executed
# CPU utilization: 105.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 91.6% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 101.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.2% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1014 executed
# CPU utilization: 95.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.4% | RAM utilization: 1.8003590545398729%
# CPU utilization: 111.8% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.8% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1015 executed
# CPU utilization: 106.3% | RAM utilization: 1.8003590545398729%
# CPU utilization: 98.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 103.7% | RAM utilization: 1.8003590545398729%
# CPU utilization: 97.0% | RAM utilization: 1.8003590545398729%
# CPU utilization: 94.4% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1016 executed
# CPU utilization: 95.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 111.1% | RAM utilization: 1.8003590545398729%
# CPU utilization: 100.5% | RAM utilization: 1.8003590545398729%
# CPU utilization: 99.2% | RAM utilization: 1.8003590545398729%
# CPU utilization: 106.4% | RAM utilization: 1.8003590545398729%
# epoch=1,iter=1017 executed
# CPU utilization: 105.3% | RAM utilization: 1.8003590545398729%

# %%
# Prepare encrypted test data
enc_X_test = [[public_key.encrypt(j) for j in i] for i in X_test]

weights_enc = results['weights']
bias_enc = results['bias']

# %%
y_pred_enc = []
y_pred_unenc = []

test_time_start = time.time()

# Make predictions on test data
for i in enc_X_test:
    summ = sum(paillier_multiplication_cloud(p, q) for p, q in zip(i, weights_enc))
    summ = summ + bias_enc
    y_pred = sigmoid(summ)
    y_pred_enc.append(y_pred)

# Decrypt predictions
for i in y_pred_enc:
    d = private_key.decrypt(i)
    y_pred_unenc.append(1 if d >= 0.5 else 0)

test_time_end = time.time()
test_time = test_time_end - test_time_start
print(test_time)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred_unenc)
print(f'Accuracy: {accuracy}')

# %%
weights_unenc=[]
for i in weights_enc:
  p=private_key.decrypt(i)
  weights_unenc.append(p)

print(weights_unenc)

# %%
bias_unenc=private_key.decrypt(bias_enc)
print(bias_unenc)

# %%
import joblib
joblib.dump((weights_unenc, bias_unenc, accuracy, y_pred_unenc, cpu_seconds, cpu_usages, ram_usages, results['train_time'], test_time), 'variables_paillier.pkl')

# %%
time.sleep(11600)
